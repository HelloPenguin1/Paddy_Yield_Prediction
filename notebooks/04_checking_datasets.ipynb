# %%
# Load both datasets and display the first 5 rows
import pandas as pd

path_tree = r"c:\dev\Paddy_Prediction\data\after_Feature_Selection\rf_selected_tree.csv"
path_classic = r"c:\dev\Paddy_Prediction\data\after_Feature_Selection\rf_selected_classic.csv"

df_tree = pd.read_csv(path_tree)
df_classic = pd.read_csv(path_classic)

print("--- Tree-selected dataset (top 5) ---")
display(df_tree.head())

print("--- Classic-selected dataset (top 5) ---")
display(df_classic.head())
# Out:
# --- Tree-selected dataset (top 5) ---
#    Micronutrients_70Days  Potassh_50Days  Nursery area (Cents)  \
# 0                   90.0        1.587832                 120.0
# 1                   90.0        1.587832                 120.0
# 2                   90.0        1.587832                 120.0
# 3                   90.0        1.587832                 120.0
# 4                   90.0        1.587832                 120.0
#
#    Seedrate(in Kg)  Hectares   Urea_40Days  Weed28D_thiobencarb  DAP_20days  \
# 0            150.0        6.0     1.587832                 12.0       240.0
# 1            150.0        6.0     1.587832                 12.0       240.0
# 2            150.0        6.0     1.587832                 12.0       240.0
# 3            150.0        6.0     1.587832                 12.0       240.0
# 4            150.0        6.0     1.587832                 12.0       240.0
#
#    Pest_60Day(in ml)  LP_Mainfield(in Tonnes)  Trash(in bundles)  \
# ...
